# %% [markdown]
# <a href="https://colab.research.google.com/github/jnqeras/Monkey-Island/blob/master/MonkeyIdentifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating your own dataset from Google Images

# %% [markdown]
# ##Set-up

# %% [markdown]
# Allways check that this notebook runs in a CPU: Runtime->Change Runtime Type->Hardware accelerator: GPU.
#
# The next cell in necessary since this project is runned in google colab: Actually the full solution is:
#
# 0 - Set the language of google drive to english.
#
# 1 - create a new code cell and put the following code:
#
# from google.colab import drive
# drive.mount('/content/gdrive', force_remount=True)
# root_dir = "/content/gdrive/My Drive/"
# base_dir = root_dir + 'fastai-v3/data/'
# 2 - After that you will see a link to authorize you notebook to acess you google drive, click on it, and insert the code back in you notebook.
#
# 3 - Make shure that the path is "path = Path(base_dir)
# ". And not “path = Path(‘data/monkeys’)” in the cell that contains this code:
# path = Path(base_dir)
# dest = path/folder
# dest.mkdir(parents=True, exist_ok=True)
#
# 4 - open you google drive and there will be a folder “fastai-v3” where you can upload you .txt or .csv with the lists of URLs. Note: if you upload .csv files,
# make shure that the cells that have the following text end with ".csv" and not ".txt":
#  folder = 'ateles_geoffroyi'
# file = 'urls_ateles_geoffroyi.txt'
#
# If you follow through this, this will create a foldier with 200 pictures of monkeys in your drive fastai-v3 foldier

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/dataMonkeys'
# Out:
# Mounted at /content/gdrive

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import *

# %% [markdown]
# ##Create dataset

# %% [markdown]
# ### Get a list of URLs

# %% [markdown]
# #### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# #### Download URLs into a file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# In Google Chrome press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>j</kbd> on Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>j</kbd> on macOS, and a small window the javascript 'Console' will appear. In Firefox press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>k</kbd> on Windows/Linux or <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>k</kbd> on macOS. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. Before running the following commands, you may want to disable ad blocking extensions (uBlock, AdBlockPlus etc.) in Chrome. Otherwise the window.open() command doesn't work. Then you can run the following commands:
#
# ```javascript
# urls=Array.from(document.querySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl'));
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %% [markdown]
# If you have problems download, try with `max_workers=0` to see exceptions:
# download_images(path/file, dest, max_pics=20, max_workers=0)

# %%
  folder = 'ateles_geoffroyi' 
file = 'urls_ateles_geoffroyi.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b431c07a072d> in <module>()
#       1 path = Path(base_dir)
# ----> 2 dest = path/folder
#       3 dest.mkdir(parents=True, exist_ok=True)
#
# NameError: name 'folder' is not defined

# %%
download_images(path/file, dest, max_pics=200)

# %%
  folder = 'callithrix_jacchus'
file = 'urls_callithrix_jacchus.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'cebinae'
file = 'urls_cebinae.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'cebuellea_pygmaea'
file = 'urls_cebuellea_pygmaea.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'cebus_imitator'
file = 'urls_cebus_imitator.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'chlorocebus_pygerythrus'
file = 'urls_chlorocebus_pygerythrus.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'chlorocebus_sabaeus'
file = 'urls_chlorocebus_sabaeus.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'macaca_radiata'
file = 'urls_macaca_radiata.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'mandrillus_leucophaeus'
file = 'urls_mandrillus_leucophaeus.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'nasalis_larvatus'
file = 'urls_nasalis_larvatus.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'pan_troglodytes'
file = 'urls_pan_troglodytes.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'papio_anubis'
file = 'urls_papio_anubis.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'papio_ursinus'
file = 'urls_papio_ursinus.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'pymy_squirrel'
file = 'urls_pymy_squirrel.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'rhesus_macaque'
file = 'urls_rhesus_macaque.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
folder = 'trachypithecus_obscurus'
file = 'urls_trachypithecus_obscurus.txt'

# %%
path = Path(base_dir)
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %% [markdown]
# ###Label the classes (FIXME): maybe I have to run this after each download.

# %%
classes = ['ateles_geoffroyi', 'callithrix_jacchus', 'cebinae', 'cebuellea_pygmaea', 'cebus_imitator', 'chlorocebus_pygerythrus', 'chlorocebus_sabaeus', 'macaca_radiata', 'mandrillus_leucophaeus', 'nasalis_larvatus', 'nasalis_larvatus', 'pan_troglodytes', 'papio_anubis', 'papio_ursinus', 'pymy_squirrel', 'rhesus_macaque', 'trachypithecus_obscurus'
]

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# ateles_geoffroyi
# callithrix_jacchus
# cebinae
# cebuellea_pygmaea
# cebus_imitator
# chlorocebus_pygerythrus
# chlorocebus_sabaeus
# macaca_radiata
# mandrillus_leucophaeus
# nasalis_larvatus
# nasalis_larvatus
# pan_troglodytes
# papio_anubis
# papio_ursinus
# pymy_squirrel
# rhesus_macaque
# trachypithecus_obscurus

# %% [markdown]
# ###Let's create a validation set!

# %% [markdown]
# Whenever you create a data bunch, if you don't have a separate training and validation set, then you can just say the training set is in the current folder (i.e. . because by default, it looks in a folder called train) and I want you to set aside 20% of the data. So this is going to create a validation set for you automatically and randomly. You'll see that whenever I create a validation set randomly, I always set my random seed to something fixed beforehand. This means that every time I run this code, I'll get the same validation set. In general, I'm not a fan of making my machine learning experiments reproducible (i.e. ensuring I get exactly the same results every time). The randomness is to me a really important part of finding out your is solution stable and it is going to work each time you run it. But what is important is that you always have the same validation set. Otherwise when you are trying to decide has this hyper parameter change improved my model but you've got a different set of data you are testing it on, then you don't know maybe that set of data just happens to be a bit easier. So that's why I always set the random seed here.

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# ### View data

# %% [markdown]
# Now, let's take a look at those monkeys!

# %%
data.classes
# Out:
# ['ateles_geoffroyi',
#  'callithrix_jacchus',
#  'cebinae',
#  'cebuellea_pygmaea',
#  'cebus_imitator',
#  'chlorocebus_pygerythrus',
#  'chlorocebus_sabaeus',
#  'macaca_radiata',
#  'mandrillus_leucophaeus',
#  'nasalis_larvatus',
#  'pan_troglodytes',
#  'papio_anubis',
#  'papio_ursinus',
#  'pymy_squirrel',
#  'rhesus_macaque',
#  'trachypithecus_obscurus']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %% [markdown]
# Let's examine our data set

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['ateles_geoffroyi',
#   'callithrix_jacchus',
#   'cebinae',
#   'cebuellea_pygmaea',
#   'cebus_imitator',
#   'chlorocebus_pygerythrus',
#   'chlorocebus_sabaeus',
#   'macaca_radiata',
#   'mandrillus_leucophaeus',
#   'nasalis_larvatus',
#   'pan_troglodytes',
#   'papio_anubis',
#   'papio_ursinus',
#   'pymy_squirrel',
#   'rhesus_macaque',
#   'trachypithecus_obscurus'],
#  16,
#  1184,
#  296)

# %% [markdown]
# # Train model

# %% [markdown]
# ##Basic training

# %% [markdown]
# So at that point, we can go ahead and create our convolutional neural network using that data.

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %% [markdown]
# Then run fit_one_cycle 4 times and see how we go. And we have a 27% error rate. So that's not that good.

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.085445</td>
#       <td>1.078568</td>
#       <td>0.337838</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.924288</td>
#       <td>0.975466</td>
#       <td>0.287162</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.435586</td>
#       <td>0.966117</td>
#       <td>0.270270</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.153915</td>
#       <td>0.931362</td>
#       <td>0.270270</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %% [markdown]
# This isn't great, but I'll save the progress so far, just in case.

# %%
learn.save('stage-1')

# %% [markdown]
# Then we unfreeze the rest of our model.

# %%
learn.unfreeze()

# %% [markdown]
# Then we run the learning rate finder and plot it. And we take a look.

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [4/6 00:47<00:23]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %% [markdown]
# Now we have to use the learning rate finder plot to identify the strongest downward slope that's sticking arround for quite a wild.

# %%
learn.recorder.plot()

# %%
# If the plot is not showing try to give a start and end learning rate
# learn.lr_find(start_lr=1e-5, end_lr=1e-1)
# As we can se in the upper plot, if I don't pass start and end parameters to lr_find, the plot increasees from (approx.) 1e-03 to 1e-02
# That's why we pass the following parameters
learn.lr_find(start_lr=1e-06, end_lr=1e-03)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.33% [5/6 00:58<00:11]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %% [markdown]
# Now we are able to view the behavior with more detail.
# We have to identify the period in which the learning rate deacreases the fastest for a quite long period of time, and that will be our start_lr parameter. **For end_lr we use 1e-4 or 3e-4, this is a rule of thumb.**

# %%
learn.fit_one_cycle(2, max_lr=slice(5e-05,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.669050</td>
#       <td>0.898961</td>
#       <td>0.263514</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.578834</td>
#       <td>0.873083</td>
#       <td>0.246622</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %% [markdown]
# So we've downloaded some images from Google image search, created a classifier, and we've got 28.7% error rate, let's save it.

# %%
learn.save('stage-2')

# %% [markdown]
# ##Trying to inprove.

# %% [markdown]
# ###Things that can go wrong:

# %% [markdown]
# Most of the time things will train fine with the defaults values.
#
#
# *   But sometimes that won't work, in that case, there's not much you really need to tune
#
# *  Most likely are
# ** High learnign rate:
# > If the learning rate is too high, the **validation loss will be very high (usually is under 1)**. Also if the valid_loss is too high, then the learning rate (max_lr) will high to (regardless of how many epochs it does). If this happens, there is no way to undo it, you have to go back and create your neural net again and fit from scratch with a lower learning rate.
# ** Low learning rate:
# >If the learning rate it too low, the error_rate gets better, but very slowly **(you can plot the error_rate with learn.recorder.plot_losses())**. The other thing that will happen if the learning rate is too low is that **the training loss will be higher than the validation loss (and you never will want this in your model)**.
# ** High number of epochs:
# >If the number of epochs is too high: it will produce overfitting (despite what you've heard, it's hard to overfit with deep leaning). The only thing that tells you **if you are overfitting** is that **the error rate improves for a while and then starts getting worse again** (get's smaller for a while and then starts to increase again).
# ** Low number of epochs:
# >If the number of epochs is too low, the trainging loss is much higher than the validation loss (similarly to what happens when the learning rate is too low).

# %% [markdown]
# ###Let's try to improve our error rate.

# %% [markdown]
# #### Triying to find the right parameters:

# %% [markdown]
# Let's unfreeze the model and try to adjust the learning parameters.

# %% [markdown]
# First, let's use again the lr_finder.

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='6', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [3/6 00:38<00:38]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
# If the plot is not showing try to give a start and end learning rate
# learn.lr_find(start_lr=1e-5, end_lr=1e-1)
# As we can se in the upper plot, if I don't pass start and end parameters to lr_find, the plot increasees from (approx.) 1e-03 to 1e-02
# That's why we pass the following parameters
learn.lr_find(start_lr=1e-06, end_lr=1e-03)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='6', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.33% [5/6 01:07<00:13]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %% [markdown]
# Let's run a few epochs using max_lr lower bouns as 2e-06 (seems to be the steapest descent).

# %%
learn.fit_one_cycle(6, max_lr=slice(2e-06,3e-04))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.482376</td>
#       <td>0.858305</td>
#       <td>0.233108</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.430914</td>
#       <td>0.853453</td>
#       <td>0.246622</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.368178</td>
#       <td>0.864951</td>
#       <td>0.243243</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.348880</td>
#       <td>0.870469</td>
#       <td>0.236486</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.316429</td>
#       <td>0.867608</td>
#       <td>0.243243</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# So, the train_loss is lower than the error_rate, that's good.
#
#  thing that happens when the learning rate it too low, is that the error_rate gets better (acutally, but really, really slow. This seems to be what's happening here, starting at epoch number 2: within one epoch, we were down to a 2 or 3% error rate.
#
#  Let's train with a few more epochs to be shure what's happenging.

# %%
#Create the neural net
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(12, max_lr=slice(2e-06,3e-04))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.276135</td>
#       <td>3.231366</td>
#       <td>0.929054</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.998564</td>
#       <td>2.402104</td>
#       <td>0.770270</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.466869</td>
#       <td>1.555321</td>
#       <td>0.493243</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.873963</td>
#       <td>1.221483</td>
#       <td>0.402027</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.432450</td>
#       <td>1.092547</td>
#       <td>0.361486</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# Everything seems to indicate that I have a low learning rate:
# >If the learning rate it too low, the error_rate gets better, but very slowly **(you can plot the error_rate with learn.recorder.plot_losses())**. The other thing that will happen if the learning rate is too low is that **the training loss will be higher than the validation loss (and you never will want this in your model)**.
#
# I'll increase by one order of magnitude the lower and the upper limit of the slice of max_lr.

# %%
#Create the neural net
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# %THIS!:

# %%
learn.fit_one_cycle(12, max_lr=slice(2e-05,3e-03))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.770185</td>
#       <td>1.797393</td>
#       <td>0.554054</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.618337</td>
#       <td>1.031977</td>
#       <td>0.320946</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.911299</td>
#       <td>1.052250</td>
#       <td>0.300676</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.488373</td>
#       <td>1.055515</td>
#       <td>0.283784</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.208142</td>
#       <td>1.031763</td>
#       <td>0.280405</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# Now the train_loss is lower than the valid loss (from the epoch number 6 and forward), but the error rate is still improving slowly (specially afther the first epoch).
#
# I'll increase by one order of magnitude the lower and upper limit (again).

# %%
#Create the neural net
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(12, max_lr=slice(2e-04,3e-02))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.325164</td>
#       <td>1.267278</td>
#       <td>0.304054</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.616536</td>
#       <td>1.474694</td>
#       <td>0.307432</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.370719</td>
#       <td>1.685758</td>
#       <td>0.320946</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.388949</td>
#       <td>2.317865</td>
#       <td>0.368243</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.328989</td>
#       <td>1.832564</td>
#       <td>0.310811</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# The learnign rate improves, but afther the 9th epoch, it gets dramatically worse (5%, maybe not that much dramatic), this may indicate that i'm training with too many epochs.
#
# Just to try, I'll mantain the same amount of epochs and increase the lower bound of the max_lr slice.

# %%
#Create the neural net
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(12, max_lr=slice(2e-03,3e-02))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.274596</td>
#       <td>1.291709</td>
#       <td>0.297297</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.617534</td>
#       <td>1.282890</td>
#       <td>0.293919</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.401789</td>
#       <td>2.178305</td>
#       <td>0.364865</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.486118</td>
#       <td>2.566088</td>
#       <td>0.422297</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.446358</td>
#       <td>1.957461</td>
#       <td>0.364865</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# This seems to be less clear.
#
# I'll stick to the previos lr_max, but will do less epochs.
#
# But, first,just to be shure that more epochs isn't a good option, I'll train the model with 40 epochs.

# %%
#Create the neural net
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(40, max_lr=slice(2e-04,3e-02))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.343951</td>
#       <td>1.035315</td>
#       <td>0.341216</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.609219</td>
#       <td>1.002059</td>
#       <td>0.256757</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.222023</td>
#       <td>1.087794</td>
#       <td>0.253378</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.994871</td>
#       <td>1.146258</td>
#       <td>0.283784</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.885990</td>
#       <td>1.259050</td>
#       <td>0.320946</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# mmm... I'll try to increase the learning rate, doing 40 epochs.

# %%
#Create the neural net
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(40, max_lr=slice(2e-04,7e-02))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.910063</td>
#       <td>1.424488</td>
#       <td>0.327703</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.372596</td>
#       <td>1.201270</td>
#       <td>0.293919</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.145437</td>
#       <td>1.246428</td>
#       <td>0.277027</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.008228</td>
#       <td>1.239796</td>
#       <td>0.283784</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.966686</td>
#       <td>1.581736</td>
#       <td>0.287162</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# This seems worst than the previous.

# %% [markdown]
# The model tagged with %THIS, seems to have the values we want:
# * Valid_loss under 1.
# * Train_loss under valid_loss.
#
# The only thing that doesn't convince me is that the learning rate doesn't seem to decrease that fast. But to be honest in non of the avobe it seeme to decrease that fast.
#
# I'll try this model with a few more epochs.

# %%
#Create the neural net
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(40, max_lr=slice(2e-05,3e-03))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.878900</td>
#       <td>2.472695</td>
#       <td>0.770270</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.248748</td>
#       <td>1.618576</td>
#       <td>0.476351</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.675853</td>
#       <td>1.183982</td>
#       <td>0.361486</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.167982</td>
#       <td>1.022480</td>
#       <td>0.290541</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.790842</td>
#       <td>0.977442</td>
#       <td>0.317568</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# It isn't clear the error rate is getting better.
#
# And the valid_loss is getting worse.
#
# So I'll train with 18 epochs.

# %% [markdown]
# ####And this are the final parameters:

# %%
#Create the neural net
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(18, max_lr=slice(2e-05,3e-03))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.944282</td>
#       <td>2.162118</td>
#       <td>0.692568</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.976303</td>
#       <td>1.093321</td>
#       <td>0.351351</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.218394</td>
#       <td>0.929752</td>
#       <td>0.277027</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.694031</td>
#       <td>0.931648</td>
#       <td>0.283784</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.372123</td>
#       <td>0.955505</td>
#       <td>0.277027</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# Wow, so we've improved:
# * The error_rate by ~2%.
# * The valid_loss by ~5%.
# * The train_loss by ~27%.
#
# The train_loss is lower than the valid_loss, but the error_rate doesn't decrease as fast as we'd like it to.
#
# Let's save our improvements:

# %%
learn.save('stage-3')

# %% [markdown]
# # Interpretation

# %% [markdown]
# Let's see what we've obtained
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
learn.load('stage-3');

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %% [markdown]
# The labels above the photos indicate the prediction, actuall, loss, probability

# %%
interp.plot_top_losses(9, figsize=(15,11)) #fixme: is werid that all the probabilities indicate 0.

# %%
interp.plot_confusion_matrix(figsize=(9,9), dpi=100)

# %%
interp.most_confused(min_val=2)
# Out:
# [('cebinae', 'cebus_imitator', 6),
#  ('cebus_imitator', 'cebinae', 6),
#  ('papio_anubis', 'papio_ursinus', 6),
#  ('chlorocebus_sabaeus', 'chlorocebus_pygerythrus', 5),
#  ('pymy_squirrel', 'cebuellea_pygmaea', 4),
#  ('cebuellea_pygmaea', 'pymy_squirrel', 3),
#  ('macaca_radiata', 'rhesus_macaque', 3),
#  ('papio_ursinus', 'papio_anubis', 3),
#  ('chlorocebus_pygerythrus', 'chlorocebus_sabaeus', 2),
#  ('pymy_squirrel', 'callithrix_jacchus', 2),
#  ('pymy_squirrel', 'chlorocebus_pygerythrus', 2)]

# %% [markdown]
# It's funny how the most confused is cebus imitator and cebinae, I suppouse that this species is very well named.

# %% [markdown]
# # Cleaning Up
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
# This models are pretty good at dealing with a moderate ammount of noisy data. The problem would occur if the data isn't randomly noisy, but biased noisy. If ather cleaning the data it is %0.01 better, it's fine, but still it's a good idea just to make sure that there isn't too much noise in my data in case it is biased.
#
# Using the ImageCleaner widget from fastai.widgets we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %% [markdown]
# In order to clean the entire set of images, we need to create a new dataset without the split. The video lecture demostrated the use of the `ds_type` param which no longer has any effect. See [the thread](https://forums.fast.ai/t/duplicate-widget/30975/10) for more details.

# %% [markdown]
# FIXME: check if the following code cleans the validation and the training set.

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

# db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
#                    .split_none()
#                    .label_from_df()
#                    .transform(get_transforms(), size=224)
#                    .databunch()
#      )

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
# Don't run this in google colab or any other instances running jupyter lab.
# If you do run this on Jupyter Lab, you need to restart your runtime and
# runtime state including all local variables will be lost.
#ImageCleaner(ds, idxs, path)
#The previous line is the one that can't be runned in google colab.

# %% [markdown]
# If the code above does not show any GUI(contains images and buttons) rendered by widgets but only text output, that may caused by the configuration problem of ipywidgets. Try the solution in this [link](https://github.com/fastai/fastai/issues/1539#issuecomment-505999861) to solve it.
#
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. ImageCleaner will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from top_losses.ImageCleaner(ds, idxs)
#
# You can also find duplicates in your dataset and delete them! To do this, you need to run .from_similars to get the potential duplicates' ids and then run ImageCleaner with duplicates=True. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.
#
# Make sure to recreate the databunch
# and learn_cln from the cleaned.csv file. Otherwise the file would be overwritten from scratch, losing all the results from cleaning the data from toplosses. FIXME: chequear esto.
#
# FIXME: no estoy teniendo ningún GUI.

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24' class='' max='24', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24/24 00:11<00:00]
#     </div>
# Computing similarities...

# %% [markdown]
# Fixme: check if the previous actually cleans the data set.

# %% [markdown]
# ##Re-run the model (now that the data has been cleaned)

# %% [markdown]
# # Putting the model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# This model wont be runned in a super GPU, actually it will be runned on a CPU.
# Why?
# Because it's very unliquely that this will used in a very bussy website, I don't think that many people has the urge to identify 16 species of monkey.
# For simplicity sake it will be runned on a CPU. Maybe it will take 10 or 20 times longer (0.2 seconds instead of 0.01 seconds), but is EASY TO SCALE and CHEAP.

# %% [markdown]
# Now the model is trained and we want it to predict things, that's called inference.

# %% [markdown]
# It's importat to know the order of the classes.

# %%
data.classes
# Out:
# ['ateles_geoffroyi',
#  'callithrix_jacchus',
#  'cebinae',
#  'cebuellea_pygmaea',
#  'cebus_imitator',
#  'chlorocebus_pygerythrus',
#  'chlorocebus_sabaeus',
#  'macaca_radiata',
#  'mandrillus_leucophaeus',
#  'nasalis_larvatus',
#  'pan_troglodytes',
#  'papio_anubis',
#  'papio_ursinus',
#  'pymy_squirrel',
#  'rhesus_macaque',
#  'trachypithecus_obscurus']

# %% [markdown]
# Let's test the model ona a CPU:

# %%
defaults.device = torch.device('cpu')

# %% [markdown]
# This is the monkey that we are trying to identify:

# %%
img = open_image(path/'cebinae'/'00000021.jpg')
img
# Out:
# Image (3, 190, 265)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, just make sure that `path` contains the file 'export.pkl' from before

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category cebinae

# %% [markdown]
# #YES! IT WORKS

# %% [markdown]
# #Make a webb app!

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):

# %% [markdown]
# Starlette is a toolkid to develop a web app (int needs to be installed, read how here: https://www.starlette.io/).

# %% [markdown]
# FIXME: No puedo crear la webb aplication usando starlette, quizás puedo usar otra

# %%
# !pip install -q starlette

# %%
from starlette.applications import Starlette
from starlette.responses import JSONResponse
from starlette.routing import Route

# %%
app = Starlette()

# %%
@app.route("/classify-url", methods=["GET"])
async def classify_url(request):
    bytes = await get_bytes(request.query_params["url"])
    img = open_image(BytesIO(bytes))
    _,_,losses = learner.predict(img)
    return JSONResponse({
        "predictions": sorted(
            zip(cat_learner.data.classes, map(float, losses)),
            key=lambda p: p[1],
            reverse=True
        )
    })

# %% [markdown]
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)
